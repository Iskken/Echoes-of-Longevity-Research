# %% [markdown]
# # Library Inclusion and Utilities

# %%
import pandas as pd
import numpy as np
import re

# %%
df = pd.read_csv("../../Data/ProQuest/Processed/full_df.csv")

# %%
#Loading pre-computed embeddings
X = np.load("../../Data/ProQuest/Processed/final_embed.npy")

# %%
mask = df["Full text"].fillna("").str.strip() != ""
docs = df.loc[mask, "Full text"].astype(str).tolist()

# %%
assert len(docs) == X.shape[0], f"docs={len(docs)} but embeds={X.shape[0]}"

# %%
ids = [f"doc_{i}" for i in range(len(docs))]

# %%
import chromadb

chroma_path = "./chroma_store"   # folder will be created
client = chromadb.PersistentClient(path=chroma_path)
collection = client.get_or_create_collection(name="news_articles")

# %%
batch_size = 500

for start in range(0, len(docs), batch_size):
    end = min(start + batch_size, len(docs))

    collection.add(
        ids=ids[start:end],
        documents=docs[start:end],
        embeddings=X[start:end].tolist()
    )
    
    print(f"Indexed {end}/{len(docs)}")
# Out:
# Indexed 500/52044
# Indexed 1000/52044
# Indexed 1500/52044
# Indexed 2000/52044
# Indexed 2500/52044
# Indexed 3000/52044
# Indexed 3500/52044
# Indexed 4000/52044
# Indexed 4500/52044
# Indexed 5000/52044
# Indexed 5500/52044
# Indexed 6000/52044
# Indexed 6500/52044
# Indexed 7000/52044
# Indexed 7500/52044
# Indexed 8000/52044
# Indexed 8500/52044
# Indexed 9000/52044
# Indexed 9500/52044
# Indexed 10000/52044
# Indexed 10500/52044
# Indexed 11000/52044
# Indexed 11500/52044
# Indexed 12000/52044
# Indexed 12500/52044
# Indexed 13000/52044
# Indexed 13500/52044
# Indexed 14000/52044
# Indexed 14500/52044
# Indexed 15000/52044
# Indexed 15500/52044
# Indexed 16000/52044
# Indexed 16500/52044
# Indexed 17000/52044
# Indexed 17500/52044
# Indexed 18000/52044
# Indexed 18500/52044
# Indexed 19000/52044
# Indexed 19500/52044
# Indexed 20000/52044
# Indexed 20500/52044
# Indexed 21000/52044
# Indexed 21500/52044
# Indexed 22000/52044
# Indexed 22500/52044
# Indexed 23000/52044
# Indexed 23500/52044
# Indexed 24000/52044
# Indexed 24500/52044
# Indexed 25000/52044
# Indexed 25500/52044
# Indexed 26000/52044
# Indexed 26500/52044
# Indexed 27000/52044
# Indexed 27500/52044
# Indexed 28000/52044
# Indexed 28500/52044
# Indexed 29000/52044
# Indexed 29500/52044
# Indexed 30000/52044
# Indexed 30500/52044
# Indexed 31000/52044
# Indexed 31500/52044
# Indexed 32000/52044
# Indexed 32500/52044
# Indexed 33000/52044
# Indexed 33500/52044
# Indexed 34000/52044
# Indexed 34500/52044
# Indexed 35000/52044
# Indexed 35500/52044
# Indexed 36000/52044
# Indexed 36500/52044
# Indexed 37000/52044
# Indexed 37500/52044
# Indexed 38000/52044
# Indexed 38500/52044
# Indexed 39000/52044
# Indexed 39500/52044
# Indexed 40000/52044
# Indexed 40500/52044
# Indexed 41000/52044
# Indexed 41500/52044
# Indexed 42000/52044
# Indexed 42500/52044
# Indexed 43000/52044
# Indexed 43500/52044
# Indexed 44000/52044
# Indexed 44500/52044
# Indexed 45000/52044
# Indexed 45500/52044
# Indexed 46000/52044
# Indexed 46500/52044
# Indexed 47000/52044
# Indexed 47500/52044
# Indexed 48000/52044
# Indexed 48500/52044
# Indexed 49000/52044
# Indexed 49500/52044
# Indexed 50000/52044
# Indexed 50500/52044
# Indexed 51000/52044
# Indexed 51500/52044
# Indexed 52000/52044
# Indexed 52044/52044
