# %% [markdown]
# # Library Inclusion and Utilities

# %% [markdown]
# <!-- structured-notebook -->
# ## Notebook Summary
# Purpose: manually validate proposed pairings between News topics and Reddit or YouTube topics by displaying topic keywords and representative document examples side by side.
#
# Main steps:
# - Load the topic-enriched datasets needed for cross-platform comparison.
# - Use helper functions to inspect representative News/Reddit topic pairs.
# - Repeat the same manual review for News/YouTube topic pairs.

# %%
# structured-notebook-bootstrap
from pathlib import Path
import sys


def find_repo_root(start: Path) -> Path:
    start = start.resolve()
    for candidate in [start, *start.parents]:
        if (candidate / ".git").exists():
            return candidate
    return start


_repo_root = find_repo_root(Path.cwd())
if str(_repo_root) not in sys.path:
    sys.path.append(str(_repo_root))

from src.project_paths import (
    ARXIV_RAW_DIR,
    CHROMA_DIR,
    EXTERNAL_NEWS_DIR,
    GUARDIAN_DATA_DIR,
    LLM_CLASSIFICATION_DIR,
    NEWS_HTML_DIR,
    NEWS_OUTPUT_DIR,
    PREPRINT_RAW_DIR,
    PROQUEST_PROCESSED_DIR,
    PROQUEST_UNPROCESSED_DIR,
    PUBMED_PROCESSED_DIR,
    PUBMED_RAW_DIR,
    PUBLICATIONS_TABLE_DIR,
    REDDIT_DATA_DIR,
    ROOT,
    RQ1_FIGURES_DIR,
    RQ4_PLOTS_DIR,
    TOPIC_MATCHING_DIR,
    YOUTUBE_DATA_DIR,
)

# %%
import pandas as pd
import numpy as np
import itables.options as opt
from itables import show
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_out = pd.read_csv(PROQUEST_PROCESSED_DIR / 'doc_info.csv')

# %%
news_df = pd.read_csv(PROQUEST_PROCESSED_DIR / 'doc_info.csv')
reddit_df = pd.read_csv(REDDIT_DATA_DIR / 'topics.csv')
yt_df = pd.read_csv(YOUTUBE_DATA_DIR / 'data.csv')

# %% [markdown]
# <!-- structured-notebook -->
# ## How To Read This Notebook
# Each subsection below records one proposed topic match. The helper functions show representative documents and keywords so the pairing can be judged manually rather than accepted automatically.

# %% [markdown]
# # News-Reddit Pairings

# %%
def show_news_reddit(news_topic: int, reddit_topic: int):
    display(news_df[news_df['topic']==news_topic])
    print(reddit_df[reddit_df['Topic']==reddit_topic]['Representative_Docs'].tolist())

# %% [markdown]
# ## 48-3: Sleep-related

# %%
def show_topic_keys(topicNum):
    print(df_out[df_out['topic']==topicNum]['topic_keywords'].unique())

# %%
show_news_reddit(48, 3)
# Out:
#        Unnamed: 0                                              Title  \
# 6               6   Eight hours of this and I'll be ready to bag ...
# 105           105                                      Morning perks
# 461           461        21 easy ways to boost your energy instantly
# 1124         1124   'Age-reversing' millionaire Bryan Johnson sha...
# 1128         1128       Thailand: Sleep affects aging inside and out
# ...           ...                                                ...
# 46946       46946   30 min daytime nap may boost brain health, de...
# 47391       47391           The link between sleep and healthy aging
# 48086       48086   Understanding restful sleep: Causes, effects,...
# 48978       48978                     Sleep more to avoid being sick
# 51543       51543              The hollow vanity of being skinny fat
#
#                                                Full text  topic  \
# 6         GOOD NIGHT'S SLEEP HELPS YOU FEEL BETTER .....   48.0
# ...

# %% [markdown]
# ## 1-7: Skin and skincare

# %%
show_news_reddit(1, 7)
# Out:
#        Unnamed: 0                                              Title  \
# 3               3   Make your own moisturiser:   It could save yo...
# 42             42   Victoria shares her top skin care tips for th...
# 56             56         3 OF THE BEST Lush luxuries [Eire Region ]
# 110           110                                  Speciality serums
# 124           124                    BEAUTY SPOT: Fountains of youth
# ...           ...                                                ...
# 51864       51864   10 natural ways to age well:   Ditch fads and...
# 51871       51871    Everyday habits that may be secretly ageing you
# 51881       51881   'Anti-ageing' face creams make you look... ol...
# 51885       51885   CREAM TEASE:   Moisturisers have no impact on...
# 51895       51895   How to look pretty on your pension:   EDITED ...
#
#                                                Full text  topic  \
# 3         MY KITCHEN table resembles an alchemist's l...    1.0
# ...

# %% [markdown]
# ## 33-26: Fasting and Calorie restriction

# %%
show_topic_keys(33)
# Out:
# ["['fasting', 'intermittent', 'intermittent fasting', 'calories', 'longo', 'fmd', 'mattson', 'weight loss', 'insulin', 'meals', 'glucose', 'calorie', 'ramadan', '52', 'metabolic', 'mice', 'fasts', 'fastingmimicking', 'timerestricted', 'diabetes', 'valter', 'meal', 'valter longo', 'diets', 'intake', '168', 'restriction', 'periods', 'fastingmimicking diet', 'window']"]

# %%
show_news_reddit(33, 26)
# Out:
#        Unnamed: 0                                              Title  \
# 244           244               What happens to body during fasting?
# 281           281                         Health Benefits of Fasting
# 836           836   Intermittent fasting works for weight loss — ...
# 1268         1268   The longevity fast that blasts belly fat:   I...
# 1454         1454     Fasting makes us work faster, claim whizz kids
# ...           ...                                                ...
# 49830       49830       Live longer, look younger and lose weight...
# 50054       50054   Fast way to end snack attack; U.S. study with...
# 51331       51331                            FAST FORWARD, SLOW DOWN
# 52006       52006   Stay hungry: Now, fasting fuels big bucks [Sc...
# 52007       52007   Stay hungry: Now, fasting fuels big bucks [Ti...
#
#                                                Full text  topic  \
# 244     Sri Lanka, Aug. 22 -- During a fast, your bod...   33.0
# ...

# %% [markdown]
# ## 80-42: Stem Cells and Regenerative Medicine

# %%
show_topic_keys(80)
# Out:
# ["['stem', 'stem cell', 'stem cells', 'cell therapy', 'regenerative', 'regenerative medicine', 'stemcell', 'clinics', 'therapies', 'cord', 'umbilical', 'marrow', 'bone marrow', 'tissue', 'cell treatment', 'procedures', 'berman', 'cell treatments', 'procedure', 'adult stem', 'cell therapies', 'sapse', 'umbilical cord', 'amway', 'patient', 'autologous', 'unproven', 'bone', 'tissues', 'cells used']"]

# %%
show_news_reddit(80, 42)
# Out:
#        Unnamed: 0                                              Title  \
# 140           140   Lab Dom launches its first regenerative medic...
# 377           377   Facelift! Stem cells keep Delhi women young &...
# 395           395   A timeline of success - AMWAY - CELEBRATING 4...
# 1190         1190     EWBG to set up base for promoting cell therapy
# 1306         1306   Angelo products ‘ll curb counterfeiting in Ni...
# ...           ...                                                ...
# 51275       51275   Medical experts must collaborate for solution...
# 51288       51288   Beware stem cell 'miracles' peddled bydoctors...
# 51530       51530   First stem cell and regenerative medicine cen...
# 51810       51810   ARE ANTI-AGEING STEM CELL JABS REALLY SAFE?: ...
# 51989       51989   United States: USRM Chief Scientist Talks Ste...
#
#                                                Full text  topic  \
# 140       Laboratoires Dom AVMM (Suisse) Inc., (Lab D...   80.0
# ...

# %% [markdown]
# ## 27-39: Exercise and Fitness

# %%
show_topic_keys(27)
# Out:
# ["['physical activity', 'walking', 'vigorous', 'sedentary', 'sitting', 'moderate', 'exercising', 'intensity', 'muscles', 'researchers', 'inactive', 'regular exercise', 'exercises', '150 minutes', 'aerobic', 'cardiovascular', 'strength training', 'workout', 'adults', 'exercised', 'minutes day', 'zone', 'physically', 'gym', 'participants', 'brisk', 'lower risk', 'diabetes', 'heart disease', 'minutes week']"]

# %%
show_news_reddit(27, 39)
# Out:
#        Unnamed: 0                                              Title  \
# 641           641   The dream of toned abs and a tight butt might...
# 1803         1803                                 WEEKLY TIP PACKAGE
# 2729         2729     CUBICLE NATION MUST ADJUST FOR AGING WORKFORCE
# 3079         3079   Here's the new silver standard for fitness:  ...
# 3123         3123   Promote yourself to chief executive officer f...
# ...           ...                                                ...
# 50043       50043   13 Scientifically Proven Health Benefits Of E...
# 50636       50636   You can't beat varied workouts to keep the he...
# 51211       51211   C-Suite: Health -- The Informed Patient: The ...
# 51213       51213                                           No Title
# 51504       51504             How walking can increase your lifespan
#
#                                                Full text  topic  \
# 641     The dream of toned abs and a tight butt might...   27.0
# ...

# %% [markdown]
# ## 69-4: Testosterone, libido, estrogen

# %%
show_topic_keys(69)
# Out:
# ["['testosterone', 'testosterone levels', 'prostate', 'low testosterone', 'dysfunction', 'erectile', 'sexual', 'hormone', 'erectile dysfunction', 'testosterone therapy', 'gainswave', 'hypogonadism', 'sex', 'symptoms', 'prostate cancer', 'male', 'hims', 'morgentaler', 'erection', 'replacement', 'men low', 'older men', 'replacement therapy', 'libido', 'ed', 'risks', 'testosterone replacement', 'sexual performance', 'sex drive', 'fda']"]

# %%
show_news_reddit(69, 4)
# Out:
#        Unnamed: 0                                              Title  \
# 1723         1723      The Big T: Could It Get Me to 95 +?:   Health
# 1732         1732   Testing Testosterone; The Big T: Could it get...
# 1744         1744   Can big T get me to 95-plus?; Low testosteron...
# 1745         1745   Taking testosterone therapy; Could the Big T ...
# 2570         2570   Testosterone May Help Fight Diabetes in Baby ...
# ...           ...                                                ...
# 51614       51614   United States: The Colorado Center for Health...
# 51660       51660   United States: New Orleans' GAINSWave Offers ...
# 51703       51703   United States: Prestige Wellness Institute Of...
# 51717       51717   United States: Age Management Center Brings G...
# 52015       52015   United States: GAINSWave ED Regenerative Trea...
#
#                                                Full text  topic  \
# 1723    Should aging males use testosterone therapy t...   69.0
# ...

# %% [markdown]
# ## 96-31: Coffe,tea,drinks

# %%
show_news_reddit(96, 31)
# Out:
#        Unnamed: 0                                              Title  \
# 3697         3697   Can hot chocolate change your life?:   Forget...
# 4487         4487   Pakistan: Greek coffee could be key to long life
# 4490         4490   Pakistan: Greek coffee could be key to long l...
# 4492         4492             Greek coffee could be key to long life
# 4622         4622        Greek coffee may be the potion of long life
# ...           ...                                                ...
# 51973       51973           Jitter juice has a dark, disgusting side
# 51974       51974            The dark side of jitter juice:   Coffee
# 51985       51985                      5 health benefits of caffeine
# 52014       52014   United States: Bulletproof Supports Massive G...
# 52037       52037   On conflicting grounds; How a coffee a day ca...
#
#                                                Full text  topic  \
# 3697    I'M the first to admit that I love trying wei...   96.0
# ...

# %% [markdown]
# ## 7-12: Senescent cells

# %%
show_topic_keys(7)
# Out:
# ["['mice', 'rapamycin', 'metformin', 'senescent', 'telomeres', 'senescent cells', 'humans', 'drugs', 'researchers', 'lifespan', 'agerelated', 'animals', 'diabetes', 'telomerase', 'telomere', 'gene', 'trials', 'klotho', 'genes', 'agerelated diseases', 'cellular', 'extend', 'alzheimers', 'dna', 'senescence', 'ageing process', 'protein', 'trial', 'mouse', 'zombie']"]

# %%
show_news_reddit(7, 12)
# Out:
#        Unnamed: 0                                              Title  \
# 541           541   Alzheimer test could hold the key to living l...
# 632           632   G2: Shortcuts: Science: Age shall not wither him
# 996           996   How a low-cost diabetes drug metformin can sl...
# 1249         1249   The four common medicines that could help pro...
# 1303         1303   Remaining illness-free as lifespan continues ...
# ...           ...                                                ...
# 51706       51706   United States: New Book by Anti-Aging Pioneer...
# 51849       51849     'Thread of life' protein could tackle diseases
# 51850       51850                       Protein could tackle disease
# 51852       51852              Secret of longevity protein revealed!
# 51872       51872   The fight against aging that might soon be a ...
#
#                                                Full text  topic  \
# 541       A YELLOW dye used in the diagnosis of Alzhe...    7.0
# ...

# %% [markdown]
# ## 11-2: Dementia, Alzheimer's, brain, decline

# %%
show_news_reddit(11, 2)
# Out:
#        Unnamed: 0                                              Title  \
# 132           132   Overuse of the brain may lead to early aging,...
# 410           410                  Our irrational fear of forgetting
# 727           727   Reboot your brain - and ward of fdementia:   ...
# 774           774   Mind games; Puzzles, chess, other pursuits ca...
# 1725         1725   SCIENCE FILE; Brain training may delay dement...
# ...           ...                                                ...
# 50112       50112         Maintain brain health in your golden years
# 50297       50297   A heart-attack reality check for Valentine's Day
# 50314       50314   To live long and prosper, practice cultivatin...
# 50724       50724   CUT THIS OUT AND PUT IT ON YOUR FRIDGE! TIPS ...
# 51987       51987              GET SMART HOW TO BUILD A BETTER BRAIN
#
#                                                Full text  topic  \
# 132       (ProQuest: ... denotes non-USASCII text omi...   11.0
# ...

# %% [markdown]
# ## 34-17: Covid-19

# %%
show_news_reddit(34, 17)
# Out:
#        Unnamed: 0                                              Title  \
# 773           773   Post offers up misinformation about viruses, ...
# 1005         1005   Inadequate sleep, abdominal fat accelerating ...
# 1459         1459                                  SHINGLES JAB PLEA
# 1467         1467              SHINGLES JAB PLEA [Northeast Region ]
# 3311         3311   Study on dementia cases in city underway:   N...
# ...           ...                                                ...
# 49957       49957       The List: Five prizes for changing the world
# 50346       50346   Helen Dennis: Recuperation takes longer as we...
# 51581       51581   Dr. BK Modi launches India's first and most i...
# 51741       51741     SENS arrives to give a younger, healthier life
# 51786       51786   HEALTHY AGING: Facilities for seniors lock do...
#
#                                                Full text  topic  \
# 773     The claim: Amish people live longer, do not h...   34.0
# ...

# %% [markdown]
# ## 4-20: Biological Age, epigenetic

# %%
show_topic_keys(4)
# Out:
# ["['biological', 'biological age', 'immortality', 'genes', 'dna', 'lifespan', 'cryonics', 'die', 'humans', 'epigenetic', 'genetic', 'calico', 'silicon', 'researchers', 'agerelated', 'google', 'altos', 'gene', 'thiel', 'bezos', 'drugs', 'grey', 'biology', 'silicon valley', 'telomeres', 'extend', 'organs', 'live longer', 'forever', 'molecular']"]

# %%
show_news_reddit(4, 20)
# Out:
#        Unnamed: 0                                              Title  \
# 277           277   Longevity: Habits May Extend Life Only So Muc...
# 284           284                                 Longevity in genes
# 288           288   It's all in the genes: DNA, not lifestyle is ...
# 726           726   No one can live for ever, no matter what it s...
# 759           759   Humans are perhaps the only species that know...
# ...           ...                                                ...
# 51734       51734   LIFE… UNLIMITED:   Beating ageing is set to b...
# 51798       51798                   The men who want to live forever
# 51830       51830   It's not fiction: we will live longer and pro...
# 51941       51941          Science is set to take us beyond humanity
# 52021       52021                                         Paperbacks
#
#                                                Full text  topic  \
# 277     The eating, drinking and exercise habits of e...    4.0
# ...

# %% [markdown]
# ## 10-75: Cancer, Sun exposure

# %%
show_news_reddit(10, 75)
# Out:
#        Unnamed: 0                                              Title  \
# 16             16                                          30 is the
# 311           311   BEAUTY SCHOOL:   [DANIELLE LINEKER'S BEAUTY B...
# 341           341   New sunscreens do more than just protect your...
# 452           452   HELPING HANDS:   Constant exposure to the sun...
# 502           502   3 HEALTH expert Dr JOANNA LONGSTAFFE Clinical...
# ...           ...                                                ...
# 51596       51596    Beauty: The lazy girl's guide to sun protection
# 51600       51600               Time to get taps aff.. the sunscreen
# 51604       51604   Tan-tastic user-friendly sun care essentials ...
# 51690       51690                         The best mineral sunscreen
# 51856       51856             Why should sunscreen be used in winter
#
#                                                Full text  topic  \
# 16      Swot up on the latest sunscreens for summer E...   10.0
# ...

# %% [markdown]
# ## 109-53: Cannabis, marijuana

# %%
show_topic_keys(109)
# Out:
# ["['cbd', 'cannabis', 'hemp', 'thc', 'cbd oil', 'marijuana', 'cbd products', 'financialbuzzcom', 'cannabidiol', 'cannabinoids', 'legal', 'tincture', 'plant', 'spectrum', 'hemp seed', 'topical', 'mct oil', 'salve', 'seed', 'mct', 'relief', 'medical cannabis', 'creams', 'naturals', 'seed oil', 'tinctures', 'medical marijuana', 'pain relief', 'tor', 'balm']"]

# %%
show_news_reddit(109, 53)
# Out:
#        Unnamed: 0                                              Title  \
# 1045         1045   Does CBD-Infused Skin Care Actually Do Anythi...
# 4038         4038   From face masks to designer clothes, startup ...
# 7339         7339                                     Weed out lines
# 7340         7340                       Weed can roll back the years
# 7341         7341   Boffins use super-strength cannabis to create...
# ...           ...                                                ...
# 51975       51975   United States: CBD Naturals to Launch Brand-N...
# 51978       51978   United States: Cannabis Innovator Carlsbad Na...
# 51979       51979   United States: Industry Leader CBD Naturals t...
# 51992       51992   United States: Growing Cannabis Sales Expecte...
# 51993       51993   United States: Spending on Legal Cannabis Pro...
#
#                                                Full text  topic  \
# 1045    Catherine Falls Commercial via Getty Images S...  109.0
# ...

# %% [markdown]
# ## 28-65: Bryan Johnson

# %%
show_news_reddit(28, 65)
# Out:
#        Unnamed: 0                                              Title  \
# 780           780   Biohacker Bryan Johnson's quest is to stall a...
# 832           832   The secrets behind LeBron James’s biohacking ...
# 833           833   Biohacker who transferred son's blood to stay...
# 834           834   Millionaire injects himself in attempt to ‘ag...
# 920           920   'Marna Mat': Age-reversing millionaire Bryan ...
# ...           ...                                                ...
# 48690       48690   Meet the man who is ageing backwards:   The m...
# 48808       48808                                Roll back the years
# 51369       51369   Extreme biohacking: the tech guru who spent $...
# 51769       51769                                  Beating the clock
# 51976       51976   United States: Bulletproof Announces Official...
#
#                                                Full text  topic  \
# 780     The death dogma is understandable. No one in ...   28.0
# ...

# %% [markdown]
# ## 0-0: Assisted living, nursing homes

# %%
show_topic_keys(0)
# Out:
# ["['seniors', 'communities', 'nursing', 'programs', 'healthy aging', 'residents', 'homes', 'housing', 'older adults', 'adults', 'organizations', 'caregivers', 'health care', 'funding', 'brunswick', 'new brunswick', 'government', 'county', 'longterm care', 'projects', 'volunteer', 'nursing homes', 'nursing home', 'agefriendly', 'volunteers', 'council', 'province', 'meals', 'organization', 'transportation']"]

# %%
show_news_reddit(0, 0)
# Out:
#        Unnamed: 0                                              Title  \
# 23             23                                        help wanted
# 68             68   Scheme lets you lease a scooter:   ADVERTISEM...
# 592           592   Business digest:   Youthful Endeavors MedSpa ...
# 730           730   Elder caregiver support 'needs to be funded a...
# 885           885   Sandwich Generation Gets Squeezed --- Millenn...
# ...           ...                                                ...
# 51814       51814   HEALTHY AGING: AARP tax aide program turns 50...
# 51857       51857   HEALTHY AGING: Advocates focusing on senior r...
# 51875       51875   Arnprior, township plan for seniors' drop-in ...
# 51966       51966   Tom 'Mr. Perfect' Browning Roast & Toast bene...
# 52028       52028   Left to the Tides and Fighting for Time:   [S...
#
#                                                Full text  topic  \
# 23      Zachary Kaufman/The Columbian Gerontology stu...    0.0
# ...

# %% [markdown]
# <!-- structured-notebook -->
# ## Second Review Pass
# The notebook now switches from News-Reddit comparisons to News-YouTube comparisons, using the same manual validation pattern.

# %% [markdown]
# # News-Youtube Pairings

# %%
def show_news_yt(news_topic: int, yt_topic: int):
    display(news_df[news_df['topic']==news_topic].head())
    display(yt_df[yt_df['topic']==yt_topic].head())

# %% [markdown]
# ## 33-32: Fasting and calorie restriction

# %%
show_topic_keys(33)
# Out:
# ["['fasting', 'intermittent', 'intermittent fasting', 'calories', 'longo', 'fmd', 'mattson', 'weight loss', 'insulin', 'meals', 'glucose', 'calorie', 'ramadan', '52', 'metabolic', 'mice', 'fasts', 'fastingmimicking', 'timerestricted', 'diabetes', 'valter', 'meal', 'valter longo', 'diets', 'intake', '168', 'restriction', 'periods', 'fastingmimicking diet', 'window']"]

# %%
show_news_yt(33,32)
# Out:
#       Unnamed: 0                                              Title  \
# 244          244               What happens to body during fasting?
# 281          281                         Health Benefits of Fasting
# 836          836   Intermittent fasting works for weight loss — ...
# 1268        1268   The longevity fast that blasts belly fat:   I...
# 1454        1454     Fasting makes us work faster, claim whizz kids
#
#                                               Full text  topic  \
# 244    Sri Lanka, Aug. 22 -- During a fast, your bod...   33.0
# 281    Srinagar, Aug. 5 -- There has been much conte...   33.0
# 836    More studies suggest the tactic can help you ...   33.0
# 1268   It sounds too good to be true. A five-day die...   33.0
# 1454     UNITED STATES: Obsessive technology workers...   33.0
#
#                                          topic_keywords
# 244   ['fasting', 'intermittent', 'intermittent fast...
# 281   ['fasting', 'intermittent', 'intermittent fast...
# ...

# %% [markdown]
# ## 27-8: Exercise and Fitness

# %%
show_news_yt(27,8)
# Out:
#       Unnamed: 0                                              Title  \
# 641          641   The dream of toned abs and a tight butt might...
# 1803        1803                                 WEEKLY TIP PACKAGE
# 2729        2729     CUBICLE NATION MUST ADJUST FOR AGING WORKFORCE
# 3079        3079   Here's the new silver standard for fitness:  ...
# 3123        3123   Promote yourself to chief executive officer f...
#
#                                               Full text  topic  \
# 641    The dream of toned abs and a tight butt might...   27.0
# 1803     Respect your elders As he approached his 11...   27.0
# 2729   I've been envisioning the office cubicle of t...   27.0
# 3079   Recent studies have shown that physical exerc...   27.0
# 3123     Just in startling stats on exercise from Ha...   27.0
#
#                                          topic_keywords
# 641   ['physical activity', 'walking', 'vigorous', '...
# 1803  ['physical activity', 'walking', 'vigorous', '...
# ...

# %% [markdown]
# ## 11-3: Dementia, Alzheimer's, brain, decline

# %%
show_news_yt(11,3)
# Out:
#       Unnamed: 0                                              Title  \
# 132          132   Overuse of the brain may lead to early aging,...
# 410          410                  Our irrational fear of forgetting
# 727          727   Reboot your brain - and ward of fdementia:   ...
# 774          774   Mind games; Puzzles, chess, other pursuits ca...
# 1725        1725   SCIENCE FILE; Brain training may delay dement...
#
#                                               Full text  topic  \
# 132      (ProQuest: ... denotes non-USASCII text omi...   11.0
# 410      In our hypercognitive society, fear of memo...   11.0
# 727    As we head into midlife, memory issues can be...   11.0
# 774    Experts say methods to keep our minds sharp a...   11.0
# 1725     If you're intent on keeping dementia at bay...   11.0
#
#                                          topic_keywords
# 132   ['dementia', 'alzheimers', 'cognitive', 'alzhe...
# 410   ['dementia', 'alzheimers', 'cognitive', 'alzhe...
# ...

# %% [markdown]
# ## 116-33: Red-light therapy

# %%
show_topic_keys(116)
# Out:
# ["['light therapy', 'red light', 'mask', 'led light', 'lights', 'rlt', 'device', 'wavelengths', 'acne', 'infrared', 'blue light', 'masks', 'collagen', 'led therapy', 'leds', 'devices', 'led lights', 'led mask', 'wrinkles', 'nearinfrared', 'inflammation', 'healing', 'led face', 'yellow', 'athome', 'laser', 'face mask', 'wavelength', 'skincare', 'bacteria']"]

# %%
show_news_yt(116,33)
# Out:
#       Unnamed: 0                                              Title  \
# 673          673   Why I swapped Creme de la Mer for supermarket...
# 880          880   French brand to present innovations at Beauty...
# 1000        1000                 DO I REALLY NEED... [Scot Region ]
# 1034        1034   So are 'anti-ageing' LED masks really such a ...
# 1056        1056   LED light therapy: The hottest skincare trend...
#
#                                               Full text  topic  \
# 673      WI T H t h e recession in ful l swing and b...  116.0
# 880    Lucibel. le to French brand Lucibel. le, spec...  116.0
# 1000   THIS WEEK: Anti-blemish LED Light Therapy Fac...  116.0
# 1034   THEY get a glowing review from stars such as ...  116.0
# 1056   New Delhi, Aug. 10 -- If you've been scrollin...  116.0
#
#                                          topic_keywords
# 673   ['light therapy', 'red light', 'mask', 'led li...
# 880   ['light therapy', 'red light', 'mask', 'led li...
# ...

# %% [markdown]
# ## 28-1: Biohacker Dave Asprey (Bryan johnson in news)

# %%
show_news_yt(28,1)
# Out:
#      Unnamed: 0                                              Title  \
# 780         780   Biohacker Bryan Johnson's quest is to stall a...
# 832         832   The secrets behind LeBron James’s biohacking ...
# 833         833   Biohacker who transferred son's blood to stay...
# 834         834   Millionaire injects himself in attempt to ‘ag...
# 920         920   'Marna Mat': Age-reversing millionaire Bryan ...
#
#                                              Full text  topic  \
# 780   The death dogma is understandable. No one in ...   28.0
# 832   At 39, LeBron James continues to dominate the...   28.0
# 833   Bryan Johnson will stop at nothing while tryi...   28.0
# 834   Bryan Johnson, known for embarking on outland...   28.0
# 920   Bryan Johnson, a millionaire tech entrepreneu...   28.0
#
#                                         topic_keywords
# 780  ['johnson', 'bryan', 'blueprint', 'bryan johns...
# 832  ['johnson', 'bryan', 'blueprint', 'bryan johns...
# ...

# %% [markdown]
# ## 45-18: Food, superfood

# %%
show_topic_keys(45)
# Out:
# ["['vegetables', 'carrots', 'purple', 'foods', 'vitamin', 'fibre', 'fruits', 'nutrients', 'antioxidants', 'kale', 'spinach', 'vegetable', 'peas', 'superfoods', 'greens', 'berries', 'asparagus', 'vitamins', 'iron', 'broccoli', 'fruits vegetables', 'sweet', 'seeds', 'potassium', 'superfood', 'potatoes', 'juice', 'cabbage', 'tomatoes', 'minerals']"]

# %%
show_news_yt(45,18)
# Out:
#      Unnamed: 0                                              Title  \
# 135         135                          Do you taste the Rainbow?
# 382         382                        Eve was right: eat an apple
# 392         392                 SPINACH ... RICH IN IRON AND FIBRE
# 499         499                             Eat a rainbow each day
# 548         548   Eating a rainbow of foods is essential to goo...
#
#                                              Full text  topic  \
# 135   You've probably heard the popular tagline "ta...   45.0
# 382   New evidence just keeps on polishing the rep ...   45.0
# 392   This dark leafy vegetable packs a powerful nu...   45.0
# 499   When kids colour pictures, they use a variety...   45.0
# 548     National Nutrition Month is almost over, bu...   45.0
#
#                                         topic_keywords
# 135  ['vegetables', 'carrots', 'purple', 'foods', '...
# 382  ['vegetables', 'carrots', 'purple', 'foods', '...
# ...

# %% [markdown]
# ## 115-0: Drug, nootropics

# %%
show_topic_keys(115)
# Out:
# ["['nootropics', 'modafinil', 'drugs', 'smart drugs', 'tinnitus', 'synapse xt', 'xt', 'synapse', 'nootropic', 'cognitive', 'repa', 'caffeine', 'students', 'pills', 'cubes', 'ltheanine', 'alertness', 'coffee', 'limitless', 'nootrobox', 'eddie', 'supplement', 'supplements', 'prescription', 'enhancers', 'enhancement', 'substances', 'adhd', 'hearing', 'concentration']"]

# %%
show_news_yt(115,0)
# Out:
#       Unnamed: 0                                              Title  \
# 1438        1438   Smart drugs latest trend to boost focus; NOOT...
# 1439        1439   Brain-boosting drugs a 'murky area'; 'Nootrop...
# 1440        1440   Brain-boosting drugs fill a need for those lo...
# 1441        1441   Smart drugs latest trend to boost focus; Noot...
# 1534        1534                For A Sharper Mind, Eat Your Coffee
#
#                                               Full text  topic  \
# 1438     Smart drugs are a hot brainboosting fad amo...  115.0
# 1439     Smart drugs are a hot brainboosting fad amo...  115.0
# 1440     Smart drugs are a hot brainboosting fad amo...  115.0
# 1441     Critics warn of adverse effects from self-d...  115.0
# 1534     (NAPSI)--Busy consumers today expect a lot ...  115.0
#
#                                          topic_keywords
# 1438  ['nootropics', 'modafinil', 'drugs', 'smart dr...
# 1439  ['nootropics', 'modafinil', 'drugs', 'smart dr...
# ...

# %% [markdown]
# ## 46-41: Retirement, income

# %%
show_news_yt(46,41)
# Out:
#       Unnamed: 0                                              Title  \
# 1628        1628                   Women deserve a fair go on super
# 1932        1932   Golden years turn to bronze Retirement No end...
# 2048        2048                      Fund holds in volatile market
# 2049        2049                          Future Fund returns 8.4pc
# 2078        2078                         PENSIONERS NEED FAIR SHARE
#
#                                               Full text  topic  \
# 1628     WHEN women have to extend their working yea...   46.0
# 1932     More Australians than ever intend to work b...   46.0
# 2048     INVESTMENTS THE Future Fund has navigated c...   46.0
# 2049     THE Future Fund has navigated choppy global...   46.0
# 2078     A reluctance to spend super means many reti...   46.0
#
#                                          topic_keywords
# 1628  ['superannuation', 'retirement', 'income', 'ta...
# 1932  ['superannuation', 'retirement', 'income', 'ta...
# ...

# %% [markdown]
# ## 57-34: Strength-training Muscle

# %%
show_topic_keys(57)
# Out:
# ["['menopause', 'hrt', 'symptoms', 'hormone', 'hormones', 'oestrogen', 'menopausal', 'flushes', 'hot flashes', 'hot flushes', 'flashes', 'perimenopause', 'estrogen', 'progesterone', 'hormone therapy', 'bioidentical', 'sweats', 'breast', 'breast cancer', 'hormone replacement', 'night sweats', 'replacement therapy', 'womens', 'menopausal symptoms', 'mood', 'menopause symptoms', 'thyroid', 'replacement', 'womens health', 'womans']"]

# %%
show_news_yt(57,34)
# Out:
#       Unnamed: 0                                              Title  \
# 5              5   THE HAPPY menopause PILL:   Should you try th...
# 249          249                                  THE HORMONE BOARD
# 1134        1134           The business case for managing menopause
# 2093        2093   Health issues that women face as they age Hea...
# 2209        2209   Suzanne Somers muses on Step by Step reunion,...
#
#                                               Full text  topic  \
# 5        COULD an anti-ageing supplement bought off ...   57.0
# 249    Hormones. You can't see, touch, taste or hear...   57.0
# 1134   AN OLD school friend would wake up twice nigh...   57.0
# 2093     Health issues that women face as they age N...   57.0
# 2209   Suzanne Somers admits her extensive and contr...   57.0
#
#                                          topic_keywords
# 5     ['menopause', 'hrt', 'symptoms', 'hormone', 'h...
# 249   ['menopause', 'hrt', 'symptoms', 'hormone', 'h...
# ...

# %% [markdown]
# ## 152-42: Exercise, face, yoga

# %%
show_news_yt(152,42)
# Out:
#        Unnamed: 0                                              Title  \
# 1235         1235                Face yoga may make you look younger
# 2544         2544    Open wide and smile - you'll look years younger
# 3760         3760   Do the facial slimming exercises seen on TikT...
# 8593         8593   HANNAH WADDINGHAM THE actress, 49, is [... ] ...
# 10381       10381   Does face yoga really work? We put it to the ...
#
#                                                Full text  topic  \
# 1235    We know that getting the blood flowing throug...  152.0
# 2544      Let's face it: your body can be toned throu...  152.0
# 3760    Facial exercises can only tone the muscles, n...  152.0
# 8593    HANNAH WADDINGHAM THE actress, 49, is a fan o...  152.0
# 10381   Is it possible to reshape your face minus nee...  152.0
#
#                                           topic_keywords
# 1235   ['face yoga', 'yoga', 'exercises', 'facial exe...
# ...

# %% [markdown]
# ## 88-23: Yoga, meditation

# %%
show_news_yt(88,23)
# Out:
#       Unnamed: 0                                              Title  \
# 65            65             The unconventional Yogi Ashwini [Goa ]
# 69            69                                      What is Yoga?
# 296          296   With yoga, better health is just a stretch an...
# 537          537   Yoga is practical, not 'woo woo,' says Sadie ...
# 1096        1096               Yoga- the Art, Science, and Practice
#
#                                               Full text  topic  \
# 65     PANAJI: Yoga gurus are usually associated wit...   88.0
# 69     PANJIM, Nov. 19 -- Is the question posed to u...   88.0
# 296    By MEREDITH RAINE Caller-Times Medical Writer...   88.0
# 537    An exercise that's ballooned in popularity wi...   88.0
# 1096   New Delhi, July 17 -- International Day of Yo...   88.0
#
#                                          topic_keywords
# 65    ['yoga', 'yogi', 'breathing', 'poses', 'ashwin...
# 69    ['yoga', 'yogi', 'breathing', 'poses', 'ashwin...
# ...

# %% [markdown]
# ## 108-39: Stem cells

# %%
show_news_yt(80,53)
# Out:
#       Unnamed: 0                                              Title  \
# 140          140   Lab Dom launches its first regenerative medic...
# 377          377   Facelift! Stem cells keep Delhi women young &...
# 395          395   A timeline of success - AMWAY - CELEBRATING 4...
# 1190        1190     EWBG to set up base for promoting cell therapy
# 1306        1306   Angelo products ‘ll curb counterfeiting in Ni...
#
#                                               Full text  topic  \
# 140      Laboratoires Dom AVMM (Suisse) Inc., (Lab D...   80.0
# 377      THE AMAZING potential of stem cell therapy ...   80.0
# 395    1950s: Jay Van Andel and Rich DeVos launched ...   80.0
# 1190   HYDERABAD TELANGANA Loop web application desi...   80.0
# 1306   Angelo, a new product network company from Ch...   80.0
#
#                                          topic_keywords
# 140   ['stem', 'stem cell', 'stem cells', 'cell ther...
# 377   ['stem', 'stem cell', 'stem cells', 'cell ther...
# ...

# %% [markdown]
# ## 48-21: Sleep

# %%
show_news_yt(48,21)
# Out:
#       Unnamed: 0                                              Title  \
# 6              6   Eight hours of this and I'll be ready to bag ...
# 105          105                                      Morning perks
# 461          461        21 easy ways to boost your energy instantly
# 1124        1124   'Age-reversing' millionaire Bryan Johnson sha...
# 1128        1128       Thailand: Sleep affects aging inside and out
#
#                                               Full text  topic  \
# 6        GOOD NIGHT'S SLEEP HELPS YOU FEEL BETTER .....   48.0
# 105    Just what do people do to get started in the ...   48.0
# 461    If you've ever skimped on your 7.5 hours of s...   48.0
# 1124   India, July 3 -- Tech entrepreneur Bryan John...   48.0
# 1128   As we get older, our bodies change. Fine line...   48.0
#
#                                          topic_keywords
# 6     ['sleeping', 'asleep', 'nap', 'napping', 'circ...
# 105   ['sleeping', 'asleep', 'nap', 'napping', 'circ...
# ...
